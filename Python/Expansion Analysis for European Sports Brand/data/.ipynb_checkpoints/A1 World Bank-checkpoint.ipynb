# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import zipfile as zf

# %%
zf_wb = zf.ZipFile("World Bank.zip")

# cost of living 2020
wb_costofliving = pd.read_csv(zf_wb.open("2020-cost-of-living/cost of living 2020.csv"),low_memory=False)

# Countries_and_continents_of_the_world
wb_countriescont = pd.read_csv(zf_wb.open("Countries_and_continents_of_the_world.csv"),low_memory=False)

# %%
wb_countriescont.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 51 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   temp_coldestQuart                   236 non-null    float64
#  1   temp_driestQuart                    236 non-null    float64
#  2   Agriculture                         211 non-null    object
#  3   Country Name                        269 non-null    object
#  4   Net migration                       223 non-null    object
#  5   Coastline (coast/area ratio)        226 non-null    object
#  6   Capital                             243 non-null    object
#  7   accessibility_to_cities             237 non-null    float64
#  8   Population 2020                     46 non-null     float64
#  9   Population                          226 non-null    float64
#  10  Climate_short_desc                  204 non-null    object
# ...

# %%
wb_countriescont.head(10)
# Out:
#    temp_coldestQuart  temp_driestQuart Agriculture       Country Name  \
# 0          -0.261352         21.120329        0,38        Afghanistan
# 1          -4.101205         -1.280922         NaN      Aland Islands
# 2           3.579896         19.573206       0,232            Albania
# 3          13.151553         26.921072       0,101            Algeria
# 4          25.696020         25.859011         NaN     American Samoa
# 5          -1.989975          4.336232         NaN            Andorra
# 6          18.793516         18.866882       0,096             Angola
# 7          25.493355         25.886688        0,04           Anguilla
# 8                NaN               NaN         NaN         Antarctica
# 9          24.723990         25.226852       0,038  Antigua & Barbuda
#
#   Net migration Coastline (coast/area ratio)           Capital  \
# 0         23,06                         0,00             Kabul
# 1           NaN                          NaN         Mariehamn
# ...

# %%
zf_aus = zf.ZipFile("AustraliaChains.xlsx.zip", "r")
aus_chains = pd.read_excel(zf_aus.open("AustraliaChains.xlsx"))
